# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

key = '1c3f5c130800f01d6484269bc0f70741'
company = 'AAPL'
years = 2

url_income_statement_json = f'https://financialmodelingprep.com/api/v3/income-statement/{company}?limit={years}&apikey={key}'
url_income_statement_csv = f'https://financialmodelingprep.com/api/v3/income-statement/{company}?datatype=csv&limit={years}&apikey={key}'

income_statement_json = requests.get(url_income_statement_json)
income_statement_json = income_statement_json.json()

# income_statement_csv = requests.get(url_income_statement_csv)
# with open('data.csv', 'wb') as f:
#     f.write(income_statement_csv.content)
# income_statement_df = pd.read_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [15], in <cell line: 18>()
#      16 with open('data.csv', 'wb') as f:
#      17     f.write(income_statement_csv.content)
# ---> 18 income_statement_df = pd.read_csv('data.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
income_statement_df = pd.read_csv('data.csv')
income_statement_df
# Out:
#                  date                        Unnamed: 1  2022-09-24_FY  \
# 0                 NaN                           revenue   3.943280e+11
# 1                 NaN                     costOfRevenue   2.235460e+11
# 2                 NaN                       grossProfit   1.707820e+11
# 3                 NaN                  grossProfitRatio   4.330963e-01
# 4   COST And EXPENSES                               NaN            NaN
# 5                 NaN    ResearchAndDevelopmentExpenses   2.625100e+10
# 6                 NaN  GeneralAndAdministrativeExpenses   0.000000e+00
# 7                 NaN       SellingAndMarketingExpenses   0.000000e+00
# 8                 NaN                     otherExpenses   0.000000e+00
# 9                 NaN                 operatingExpenses   5.134500e+10
# 10                NaN                   costAndExpenses   2.748910e+11
# 11                NaN                   interestExpense   0.000000e+00
# ...

# %%
print(income_statement_json[0]['revenue'])
# Out:
# 394328000000

# %%
print(income_statement_json[1]['grossProfit'])
# Out:
# 152836000000

# %%
print(income_statement_json[0]['eps'])
# Out:
# 6.15

# %%
url_balance_sheet = f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{company}?limit={years}&apikey={key}'
balance_sheet = requests.get(url_balance_sheet)

# %%
balance_sheet_json = balance_sheet.json()
balance_sheet_json
# Out:
# [{'date': '2022-09-24',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2022-10-28',
#   'acceptedDate': '2022-10-27 18:01:14',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'cashAndCashEquivalents': 23646000000,
#   'shortTermInvestments': 24658000000,
#   'cashAndShortTermInvestments': 48304000000,
#   'netReceivables': 60932000000,
#   'inventory': 4946000000,
#   'otherCurrentAssets': 21223000000,
#   'totalCurrentAssets': 135405000000,
#   'propertyPlantEquipmentNet': 42117000000,
#   'goodwill': 0.0,
#   'intangibleAssets': 0.0,
#   'goodwillAndIntangibleAssets': 0.0,
#   'longTermInvestments': 120805000000,
#   'taxAssets': 0.0,
#   'otherNonCurrentAssets': 54428000000,
#   'totalNonCurrentAssets': 217350000000,
#   'otherAssets': 0.0,
#   'totalAssets': 352755000000,
#   'accountPayables': 64115000000,
#   'shortTermDebt': 21110000000,
#   'taxPayables': 0.0,
#   'deferredRevenue': 7912000000,
# ...

# %%
url_cash_flow = f'https://financialmodelingprep.com/api/v3/cash-flow-statement/{company}?limit={years}&apikey={key}'
cash_flow = requests.get(url_cash_flow)
cash_flow_json = cash_flow.json()

# %%
cash_flow_json
# Out:
# [{'date': '2022-09-24',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2022-10-28',
#   'acceptedDate': '2022-10-27 18:01:14',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'netIncome': 99803000000,
#   'depreciationAndAmortization': 11104000000,
#   'deferredIncomeTax': 895000000,
#   'stockBasedCompensation': 9038000000,
#   'changeInWorkingCapital': 1200000000,
#   'accountsReceivables': -1823000000,
#   'inventory': 1484000000,
#   'accountsPayables': 9448000000,
#   'otherWorkingCapital': 478000000,
#   'otherNonCashItems': 111000000,
#   'netCashProvidedByOperatingActivities': 122151000000,
#   'investmentsInPropertyPlantAndEquipment': -10708000000,
#   'acquisitionsNet': -306000000,
#   'purchasesOfInvestments': -76923000000,
#   'salesMaturitiesOfInvestments': 67363000000,
#   'otherInvestingActivites': -1780000000,
#   'netCashUsedForInvestingActivites': -22354000000,
#   'debtRepayment': -9543000000,
# ...
