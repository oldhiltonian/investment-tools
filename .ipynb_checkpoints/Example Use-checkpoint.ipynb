# %%
import time
import requests
import pandas as pd
from pathlib import Path
from investment_tools.fmp import FinancialData, ManualAnalysis, Company
from matplotlib import pyplot as plt
import datetime as dt
import yfinance as yf
from pandas_datareader import data as pdr
from IPython.display import clear_output
import pyarrow as pa
import numpy as np
import math
from scipy.stats import linregress

key_path = Path().home()/'desktop'/'FinancialModellingPrep_API.txt'
with open(key_path) as file:
    api_key = file.read()
    

yf.pdr_override()

# %%
a = Company('AAPL', api_key=api_key, period='annual', data='online', limit=10,
           verbose=True)
#ZTS
# Out:
# Checking matching frame indecies
# Financial statement lengths are BS: 10, IS:10, CFS:10, Ratios:10
# [*********************100%***********************]  1 of 1 completed
# Path already exists. Overwriting saved data.
# There were 0/10 values in grossProfitMargin that exceed the 0.05 error tolerance.
# There were 0/10 values in operatingProfitMargin that exceed the 0.05 error tolerance.
# There were 0/10 values in netProfitMargin that exceed the 0.05 error tolerance.
# There were 0/10 values in currentRatio that exceed the 0.05 error tolerance.
# There were 0/10 values in returnOnEquity that exceed the 0.05 error tolerance.
# There were 0/10 values in returnOnAssets that exceed the 0.05 error tolerance.
# There were 10/10 values in cashPerShare that exceed the 0.05 error tolerance.
# There were 0/10 values in interestCoverage that exceed the 0.05 error tolerance.
# There were 0/10 values in dividendPayoutRatio that exceed the 0.05 error tolerance.
# 0.18879790344550185
# ...

# %%
a.scores
# Out:
# {'eps': {'score': 0, 'strength': 0},
#  'returnOnEquity': {'score': nan, 'strength': 0},
#  'ROIC': {'score': nan, 'strength': 0},
#  'returnOnAssets': {'score': 0, 'strength': 0},
#  'debtToTotalCap': {'score': 0, 'strength': 4},
#  'totalDebtRatio': {'score': 0, 'strength': 4}}

# %%
a.eval_(a.scores)
# Out:
# False

# %%
y = a.metrics['eps']
x = range(len(y))
slope, intercept, rval, _, _ =linregress(x, y)

# %%
y = slope*x + intercept
y[0], y[-1], len(y)
# Out:
# (1.5899999999999999, 5.704285714285715, 7)

# %%
a.metrics['eps']
# Out:
# index
# AAPL-FY-2016    2.0875
# AAPL-FY-2017    2.3175
# AAPL-FY-2018    3.0025
# AAPL-FY-2019    2.9925
# AAPL-FY-2020    3.3100
# AAPL-FY-2021    5.6700
# AAPL-FY-2022    6.1500
# Name: eps, dtype: float64

# %%
math.isnan(a.metrics['eps_growth'].mean())
# Out:
# True

# %%
float(nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 float(nan)
#
# NameError: name 'nan' is not defined

# %%
c.calculated_metrics['currentRatio']
# Out:
# index
# BNS-FY-2016   NaN
# BNS-FY-2017   NaN
# BNS-FY-2018   NaN
# BNS-FY-2019   NaN
# BNS-FY-2020   NaN
# BNS-FY-2021   NaN
# BNS-FY-2022   NaN
# Name: currentRatio, dtype: float64

# %%
x = a._financial_data.reported_key_metrics['dividendPayoutRatio']

# %%
y = a.metrics['dividendPayoutRatio']

# %%
(x-y)/x
# Out:
# index
# AMZN-FY-2016   NaN
# AMZN-FY-2017   NaN
# AMZN-FY-2018   NaN
# AMZN-FY-2019   NaN
# AMZN-FY-2020   NaN
# AMZN-FY-2021   NaN
# AMZN-FY-2022   NaN
# Name: dividendPayoutRatio, dtype: float64

# %%
a.scores
# Out:
# {'eps': {'score': 4, 'strength': 0},
#  'returnOnEquity': {'score': 0, 'strength': 0},
#  'ROIC': {'score': 1, 'strength': 0},
#  'returnOnAssets': {'score': 2, 'strength': 0},
#  'debtToTotalCap': {'score': 0, 'strength': 0},
#  'totalDebtRatio': {'score': 0, 'strength': 4}}

# %%
a.metrics['debtToTotalCap'].plot()
# Out:
# <AxesSubplot:xlabel='index'>

# %%
a.export()

# %%
def tradable_tickers():
    url = f'https://financialmodelingprep.com/api/v3/available-traded/list?apikey={api_key}'
    data = requests.get(url)
    data = sort_json_ticker_data(data.json())
    return data

def sort_json_ticker_data(data):
    return_dict = dict()
    for dct in data:
        if dct['exchange'] not in return_dict.keys():
            return_dict[dct['exchange']] = [dct['symbol']]
        else:
            return_dict[dct['exchange']].append(dct['symbol'])

    return return_dict

ticker_list = tradable_tickers()

# %%
sorted(ticker_list.keys())
# Out:
# ['',
#  'American Stock Exchange',
#  'Amsterdam',
#  'Aquis AQSE',
#  'Athens',
#  'Australian Securities Exchange',
#  'BATS',
#  'BSE',
#  'Berlin',
#  'Brussels',
#  'Budapest',
#  'Buenos Aires',
#  'Canadian Sec',
#  'Copenhagen',
#  'Dubai',
#  'Dusseldorf',
#  'EGX',
#  'FTSE Index',
#  'Frankfurt',
#  'Fukuoka',
#  'HKSE',
#  'Hamburg',
#  'Helsinki',
#  'IOB',
#  'Iceland',
#  'Irish',
#  'Istanbul Stock Exchange',
#  'Jakarta Stock Exchange',
#  'Johannesburg',
#  'KOSDAQ',
#  'KSE',
#  'Kuala Lumpur',
#  'Kuwait',
#  'LSE',
#  'Lisbon',
#  'London Stock Exchange',
#  'Madrid Stock Exchange',
#  'Mexico',
#  'Milan',
#  'Munich',
#  'NASDAQ Capital Market',
#  'NASDAQ Global Market',
#  'NASDAQ Global Select',
#  'NEO',
#  'NZSE',
#  'Nasdaq',
#  'Nasdaq Capital Market',
#  'Nasdaq Global Select',
#  'National Stock Exchange of India',
#  'New York Stock Exchange',
#  'New York Stock Exchange Arca',
#  'OSE',
#  'Oslo Stock Exchange',
#  'Other OTC',
#  'Paris',
# ...

# %%
ticker_scan = (ticker_list['New York Stock Exchange'])

# %%
failed_dict = {}
for ticker in ticker_scan[:]:
    print(f"Ticker: {ticker}")
    try:
        a = Company(ticker, api_key=api_key, period='annual', data='online', limit=7,
               verbose=False)
        clear_output()
    except (AssertionError, 
            pa.ArrowTypeError) as e:
        print(e)
        if e in failed_dict.keys():
            failed_dict[e] += 1
        else:
            failed_dict[e] = 1
        clear_output()

# %%
failed_dict
# Out:
# {pyarrow.lib.ArrowTypeError("Expected bytes, got a 'int' object",
#                             'Conversion failed for column cik with type object'): 1,
#  pyarrow.lib.ArrowTypeError("Expected bytes, got a 'int' object",
#                             'Conversion failed for column cik with type object'): 1,
#  AssertionError('Financial statements are shorter than the required length of 2'): 1,
#  pyarrow.lib.ArrowTypeError("Expected bytes, got a 'int' object",
#                             'Conversion failed for column cik with type object'): 1,
#  AssertionError('Financial statements are shorter than the required length of 2'): 1,
#  pyarrow.lib.ArrowTypeError("Expected bytes, got a 'int' object",
#                             'Conversion failed for column cik with type object'): 1,
#  AssertionError('Financial statements are shorter than the required length of 2'): 1,
#  AssertionError('Indecies could not be filtered for common elements'): 1,
# ...

# %%
ticker_scan.index('GLOP-PC') - ticker_scan.index('TDC')
# Out:
# 440

# %%
company = 'RONI-UN'
period='annual'
limit=20
balance_sheets = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{company}?period={period}&limit={limit}&apikey={api_key}')

# %%
balance_sheets.json()
# Out:
# [{'date': '2021-12-31',
#   'symbol': 'RONI-UN',
#   'reportedCurrency': 'USD',
#   'cik': '0001845437',
#   'fillingDate': '2022-03-30',
#   'acceptedDate': '2022-03-30 16:00:54',
#   'calendarYear': '2021',
#   'period': 'FY',
#   'cashAndCashEquivalents': 2570409,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 2570409,
#   'netReceivables': 7960,
#   'inventory': 0,
#   'otherCurrentAssets': 746720,
#   'totalCurrentAssets': 3325089,
#   'propertyPlantEquipmentNet': 0,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 0,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': 345044341,
#   'totalNonCurrentAssets': 345044341,
#   'otherAssets': 0,
#   'totalAssets': 348369430,
#   'accountPayables': 143405,
#   'shortTermDebt': 0,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 375918,
#   'totalCurrentLiabilities': 519323,
#   'longTermDebt': 0,
# ...

# %%
ticker_scan.index('RONI-UN')
# Out:
# 2

# %%
y = a.metrics['ROIC_growth'].copy().dropna()
x = range(len(y))

# %%
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 plt.plot(x,y)
#
# NameError: name 'x' is not defined

# %%
    def replace_None(df: pd.DataFrame) -> pd.DataFrame:
        df_ = df.replace(to_replace=np.nan, value=0)
        return df_.replace(to_replace=[None,'None'], value=0)

# %%
            none_df = pd.DataFrame({'A': [1, None, 3, None, 5], 'B': [6, 7, None, 9, 10]})
            expected = pd.DataFrame({'A': [1., 0., 3., 0., 5.], 'B': [6., 7., 0., 9., 10.]})
            result = a._financial_data.replace_None(none_df)

# %%
result.equals(expected)
# Out:
# True

# %%
import random
length = 6
x = np.array(range(0, length))
y = np.array([2, 2, 3, 5, 8, 13])
x, y
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([ 2,  2,  3,  5,  8, 13]))

# %%
slope, intercept, _, _, _ = linregress(x, y)
y_ = slope*x + intercept
start, end = y_[0], y_[-1]
start, end

mean_growth = (((end/start)**(1/length)) -1)
slope, intercept, mean_growth
# Out:
# (2.142857142857143, 0.14285714285714324, 1.0581116549533673)

# %%
y = np.array([1, 2, 3, 5, 7, 9])

# %%
x = range(len(y))

# %%
x
# Out:
# range(0, 6)

# %%
y.mean()
# Out:
# 4.5
